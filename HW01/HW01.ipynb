# %% [markdown]
# ###105~110學年雙主修
# [資料來源](https://udb.moe.edu.tw/udata/DetailReportList/%E5%AD%B8%E7%94%9F%E9%A1%9E/SirdStudySituationDoubleMajor/Index)
# [大專院校名錄](https://data.gov.tw/dataset/6091)

# %%
import pandas as pd
file = "DoubleMajor(105~110).csv"
df = pd.read_csv(file)
df.head()
# Out:
#    學年度  學期 設立別  學校類別  學校統計處代碼    學校名稱      系所代碼    系所名稱     學制班別  修讀雙主修人次小計  \
# 0  105   1  公立  一般大學        1  國立政治大學  01111001    教育學系  學士班(日間)         49
# 1  105   1  公立  一般大學        1  國立政治大學  02221020    歷史學系  學士班(日間)         29
# 2  105   1  公立  一般大學        1  國立政治大學  02222031    民族學系  學士班(日間)         37
# 3  105   1  公立  一般大學        1  國立政治大學  02231022     哲學系  學士班(日間)         30
# 4  105   1  公立  一般大學        1  國立政治大學  02311009  英國語文學系  學士班(日間)         52
#
#    修讀雙主修人次男  修讀雙主修人次女
# 0        18        31
# 1        19        10
# 2         7        30
# 3        10        20
# 4        17        35

# %%
regiondata = "college_region.csv"
dfRegion = pd.read_csv(regiondata)
dfRegion.head()
# Out:
#    代碼      學校名稱 公/私立     縣市名稱                     地址            電話  \
# 0   1    國立政治大學   公立  [38]臺北市    [116]臺北市文山區指南路二段64號  (02)29393091
# 1   2    國立清華大學   公立  [18]新竹市    [300]新竹市東區光復路二段101號   (03)5715131
# 2   3    國立臺灣大學   公立  [33]臺北市    [106]臺北市大安區羅斯福路四段1號  (02)33663366
# 3   4  國立臺灣師範大學   公立  [33]臺北市  [106]臺北市大安區和平東路一段162號  (02)77491111
# 4   5    國立成功大學   公立  [21]臺南市        [701]臺南市東區大學路1號   (06)2757575
#
#                        網址    體系別
# 0  http://www.nccu.edu.tw  [1]一般
# 1  http://www.nthu.edu.tw  [1]一般
# 2   http://www.ntu.edu.tw  [1]一般
# 3  http://www.ntnu.edu.tw  [3]師範
# 4  http://www.ncku.edu.tw  [1]一般

# %% [markdown]
# 1. 雙主修的男女比(全部) (V)
# 2. 公私立學校雙主修的數量比(?) (V)
# 3. 一般大學&技專校院的雙主修人數
# 4. 各學期雙主修人數的趨勢 (V)
# 5. 各學群的雙主修數量(要有18學群的資料)(找不到學群的資料)
# 6. 不同地區雙主修的比例(?) (要有地區學校資料)(還在研究怎麼對照)
# 7. 五專、博士班、碩士班(日間)、碩士在職專班、學士班(日間)、學士班(進修)各年度
# 8. 各年度男女雙主修的趨勢 (V)
# 9.
# 10.

# %%
#雙主修的男女比(全部)
sex = pd.read_csv(file)[['修讀雙主修人次男', '修讀雙主修人次女', '修讀雙主修人次小計']].sum().reset_index()
sex
# Out:
#        index       0
# 0   修讀雙主修人次男   56610
# 1   修讀雙主修人次女   88092
# 2  修讀雙主修人次小計  144702

# %%
#各學校雙主修男女比
collegesex = pd.read_csv(file)[['學校名稱', '修讀雙主修人次男', '修讀雙主修人次女', '修讀雙主修人次小計']].groupby(['學校名稱'])['修讀雙主修人次男','修讀雙主修人次女', '修讀雙主修人次小計'].sum().reset_index()
collegesex
# Out:
# C:\Users\Pang\AppData\Local\Temp\ipykernel_11268\2741945196.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   collegesex = pd.read_csv(file)[['學校名稱', '修讀雙主修人次男', '修讀雙主修人次女', '修讀雙主修人次小計']].groupby(['學校名稱'])['修讀雙主修人次男','修讀雙主修人次女', '修讀雙主修人次小計'].sum().reset_index()
#        學校名稱  修讀雙主修人次男  修讀雙主修人次女  修讀雙主修人次小計
# 0      世新大學       458      1702       2160
# 1      中原大學       474      1217       1691
# 2    中國文化大學      1118      2543       3661
# 3    中國科技大學         5        38         43
# 4    中國醫藥大學      2716      2715       5431
# ..      ...       ...       ...        ...
# 120    靜宜大學      2370      3172       5542
# 121  高苑科技大學         9         1         10
# 122  高雄醫學大學       178       448        626
# 123  黎明技術學院         0         9          9
# 124  龍華科技大學        39        19         58
#
# [125 rows x 4 columns]

# %%
#各年度男女雙主修的趨勢
yearsex = pd.read_csv(file)[['學年度', '修讀雙主修人次男', '修讀雙主修人次女', '修讀雙主修人次小計']].groupby(['學年度'])['修讀雙主修人次男','修讀雙主修人次女', '修讀雙主修人次小計'].sum().reset_index()
yearsex
# Out:
# C:\Users\Pang\AppData\Local\Temp\ipykernel_11268\3226529983.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   yearsex = pd.read_csv(file)[['學年度', '修讀雙主修人次男', '修讀雙主修人次女', '修讀雙主修人次小計']].groupby(['學年度'])['修讀雙主修人次男','修讀雙主修人次女', '修讀雙主修人次小計'].sum().reset_index()
#    學年度  修讀雙主修人次男  修讀雙主修人次女  修讀雙主修人次小計
# 0  105      8911     14597      23508
# 1  106      8473     14063      22536
# 2  107      9486     14646      24132
# 3  108      9630     14468      24098
# 4  109      9682     14767      24449
# 5  110     10428     15551      25979

# %%
#各學校不同學年的雙主修男女比
collegeyearsex = pd.read_csv(file)[['學年度', '學校名稱', '修讀雙主修人次男', '修讀雙主修人次女', '修讀雙主修人次小計']].groupby(['學校名稱', '學年度'])['修讀雙主修人次男','修讀雙主修人次女', '修讀雙主修人次小計'].sum().reset_index()
collegeyearsex
# Out:
# C:\Users\Pang\AppData\Local\Temp\ipykernel_11268\648247839.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   collegeyearsex = pd.read_csv(file)[['學年度', '學校名稱', '修讀雙主修人次男', '修讀雙主修人次女', '修讀雙主修人次小計']].groupby(['學校名稱', '學年度'])['修讀雙主修人次男','修讀雙主修人次女', '修讀雙主修人次小計'].sum().reset_index()
#        學校名稱  學年度  修讀雙主修人次男  修讀雙主修人次女  修讀雙主修人次小計
# 0      世新大學  105        53       291        344
# 1      世新大學  106        72       289        361
# 2      世新大學  107        73       266        339
# 3      世新大學  108        86       274        360
# 4      世新大學  109        73       283        356
# ..      ...  ...       ...       ...        ...
# 659  龍華科技大學  106         5         0          5
# 660  龍華科技大學  107         8         2         10
# 661  龍華科技大學  108         3         2          5
# 662  龍華科技大學  109         9         4         13
# 663  龍華科技大學  110        10         4         14
#
# [664 rows x 5 columns]

# %%
#公私立雙主修
establish = pd.read_csv(file)[['學年度', '設立別', '修讀雙主修人次男', '修讀雙主修人次女', '修讀雙主修人次小計']].groupby(['設立別', '學年度'])['設立別', '修讀雙主修人次男','修讀雙主修人次女', '修讀雙主修人次小計'].sum().reset_index()
establish
# Out:
# C:\Users\Pang\AppData\Local\Temp\ipykernel_11268\2087282416.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   establish = pd.read_csv(file)[['學年度', '設立別', '修讀雙主修人次男', '修讀雙主修人次女', '修讀雙主修人次小計']].groupby(['設立別', '學年度'])['設立別', '修讀雙主修人次男','修讀雙主修人次女', '修讀雙主修人次小計'].sum().reset_index()
#    設立別  學年度  修讀雙主修人次男  修讀雙主修人次女  修讀雙主修人次小計
# 0   公立  105      5275      7414      12689
# 1   公立  106      4830      6866      11696
# 2   公立  107      6088      7891      13979
# 3   公立  108      6412      8068      14480
# 4   公立  109      6486      8470      14956
# 5   公立  110      6986      8975      15961
# 6   私立  105      3636      7183      10819
# 7   私立  106      3643      7197      10840
# 8   私立  107      3398      6755      10153
# 9   私立  108      3218      6400       9618
# 10  私立  109      3196      6297       9493
# 11  私立  110      3442      6576      10018

# %%
#學校類別雙主修
typeofcollege = pd.read_csv(file)[['學年度', '學校類別', '修讀雙主修人次男', '修讀雙主修人次女', '修讀雙主修人次小計']].groupby(['學校類別', '學年度'])['學校類別', '修讀雙主修人次男','修讀雙主修人次女', '修讀雙主修人次小計'].sum().reset_index()
typeofcollege
# Out:
# C:\Users\Pang\AppData\Local\Temp\ipykernel_11268\3226786895.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   typeofcollege = pd.read_csv(file)[['學年度', '學校類別', '修讀雙主修人次男', '修讀雙主修人次女', '修讀雙主修人次小計']].groupby(['學校類別', '學年度'])['學校類別', '修讀雙主修人次男','修讀雙主修人次女', '修讀雙主修人次小計'].sum().reset_index()
#     學校類別  學年度  修讀雙主修人次男  修讀雙主修人次女  修讀雙主修人次小計
# 0   一般大學  105      8354     13295      21649
# 1   一般大學  106      7745     12660      20405
# 2   一般大學  107      8703     13300      22003
# 3   一般大學  108      8892     13247      22139
# 4   一般大學  109      8937     13514      22451
# 5   一般大學  110      9628     14277      23905
# 6   技專校院  105       557      1302       1859
# 7   技專校院  106       728      1403       2131
# 8   技專校院  107       783      1346       2129
# 9   技專校院  108       738      1221       1959
# 10  技專校院  109       745      1253       1998
# 11  技專校院  110       800      1274       2074

# %%
##各科系雙主修
department = pd.read_csv(file)[['學校名稱', '系所名稱', '修讀雙主修人次男', '修讀雙主修人次女', '修讀雙主修人次小計']].groupby(['系所名稱'])['修讀雙主修人次男','修讀雙主修人次女', '修讀雙主修人次小計'].sum().reset_index()
department
# Out:
# C:\Users\Pang\AppData\Local\Temp\ipykernel_11268\2162367631.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   department = pd.read_csv(file)[['學校名稱', '系所名稱', '修讀雙主修人次男', '修讀雙主修人次女', '修讀雙主修人次小計']].groupby(['系所名稱'])['修讀雙主修人次男','修讀雙主修人次女', '修讀雙主修人次小計'].sum().reset_index()
#                  系所名稱  修讀雙主修人次男  修讀雙主修人次女  修讀雙主修人次小計
# 0              不分系學士班        52        52        104
# 1      不分系學士班_不分系學士專班         2         0          2
# 2             不動產經營學系         2         0          2
# 3          不動產與城鄉環境學系       325       434        759
# 4              中國戲劇學系        29        44         73
# ...               ...       ...       ...        ...
# 1023    高瞻科技不分系學士學位學程         8         8         16
# 1024         高齡健康管理學系        33       165        198
# 1025  高齡健康與運動科學學士學位學程         1         0          1
# 1026       高齡及長期照護事業系       123       297        420
# ...

# %%
#加上縣市作為參照
doublemajorregion = pd.merge(df, dfRegion.loc[:,['學校名稱','縣市名稱']],how = 'left', on = '學校名稱')
doublemajorregion
# Out:
#        學年度  學期 設立別  學校類別  學校統計處代碼    學校名稱      系所代碼      系所名稱     學制班別  \
# 0      105   1  公立  一般大學        1  國立政治大學  01111001      教育學系  學士班(日間)
# 1      105   1  公立  一般大學        1  國立政治大學  02221020      歷史學系  學士班(日間)
# 2      105   1  公立  一般大學        1  國立政治大學  02222031      民族學系  學士班(日間)
# 3      105   1  公立  一般大學        1  國立政治大學  02231022       哲學系  學士班(日間)
# 4      105   1  公立  一般大學        1  國立政治大學  02311009    英國語文學系  學士班(日間)
# ...    ...  ..  ..   ...      ...     ...       ...       ...      ...
# 15993  110   2  公立  一般大學     3002  臺北市立大學  10141060    球類運動學系  學士班(日間)
# 15994  110   2  公立  一般大學     3002  臺北市立大學  10141062    陸上運動學系  學士班(日間)
# 15995  110   2  公立  一般大學     3002  臺北市立大學  10141063    水上運動學系  學士班(日間)
# 15996  110   2  公立  一般大學     3002  臺北市立大學  10142052   運動健康科學系  學士班(日間)
# 15997  110   2  公立  一般大學     3002  臺北市立大學  10152050  休閒運動管理學系  學士班(日間)
#
#        修讀雙主修人次小計  修讀雙主修人次男  修讀雙主修人次女     縣市名稱
# 0             49        18        31  [38]臺北市
# ...

# %%
#各縣市雙主修的數量
#doublemajorregion_grouped = doublemajorregion.groupby(by='縣市名稱').sum()
#doublemajorregion_grouped = doublemajorregion.groupby(by=['縣市名稱', '學校名稱']).sum()

#a = doublemajorregion.sort_values(by=['縣市名稱', '學校名稱'])
region = doublemajorregion[['學年度', '縣市名稱', '修讀雙主修人次男', '修讀雙主修人次女', '修讀雙主修人次小計']].groupby(by=['縣市名稱']).sum().reset_index()
region
# Out:
#        縣市名稱  修讀雙主修人次男  修讀雙主修人次女  修讀雙主修人次小計
# 0   [01]新北市      5615     10449      16064
# 1   [02]宜蘭縣       112       138        250
# 2   [03]桃園市      3591      4519       8110
# 3   [05]苗栗縣       111        79        190
# 4   [06]臺中市      2636      3856       6492
# 5   [07]彰化縣       355       711       1066
# 6   [08]南投縣       435       787       1222
# 7   [09]雲林縣        41        67        108
# 8   [10]嘉義縣      1618      2812       4430
# 9   [11]臺南市       599       893       1492
# 10  [12]高雄市       580      1746       2326
# 11  [13]屏東縣       111       145        256
# 12  [14]臺東縣        57        79        136
# 13  [15]花蓮縣      1999      3099       5098
# 14  [16]澎湖縣         2         1          3
# 15  [17]基隆市       757       651       1408
# 16  [18]新竹市      3047      2090       5137
# 17  [19]臺中市      5550      8142      13692
# 18  [20]嘉義市       114       182        296
# 19  [21]臺南市      2604      2300       4904
# 20  [32]臺北市       157       370        527
# ...
