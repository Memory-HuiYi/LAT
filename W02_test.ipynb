# %% [markdown]
# #想要第一次讀入CSV

# %%
import pandas as pd
df = pd.read_csv('W02_test.csv')
df.head()
# Out:
#            RptNo               RptName StatCourseNo  \
# 0  10440-01-04-2  臺中市國民小學教育經費支出(預、決算數)  1044001a007
# 1  10440-01-04-2  臺中市國民小學教育經費支出(預、決算數)  1044001a007
# 2  10440-01-04-2  臺中市國民小學教育經費支出(預、決算數)  1044001a007
# 3  10440-01-04-2  臺中市國民小學教育經費支出(預、決算數)  1044001a007
# 4  10440-01-04-2  臺中市國民小學教育經費支出(預、決算數)  1044001a007
#
#                 StatCourseName              DataDate      PlaceNo PlaceName  \
# 0  國民小學教育經費支出(預、決算數)-預算數(單位:元)  2018/1/1 上午 12:00:00  10000066000       臺中市
# 1  國民小學教育經費支出(預、決算數)-預算數(單位:元)  2018/1/1 上午 12:00:00  10000066000       臺中市
# 2  國民小學教育經費支出(預、決算數)-預算數(單位:元)  2018/1/1 上午 12:00:00  10000066000       臺中市
# 3  國民小學教育經費支出(預、決算數)-預算數(單位:元)  2018/1/1 上午 12:00:00  10000066000       臺中市
# 4  國民小學教育經費支出(預、決算數)-預算數(單位:元)  2018/1/1 上午 12:00:00  10000066000       臺中市
#
#   PeriodNo PeriodName    Complex1  ... Complex5  Complex5Name DeriveNo  \
# 0        Y          年  2300100001  ...        0           NaN        0
# ...
